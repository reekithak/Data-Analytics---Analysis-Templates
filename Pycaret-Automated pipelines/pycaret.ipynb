# %%
# !pip install pycaret
from pycaret.datasets import get_data

# %%
diabetes = get_data('diabetes')
# Out:
#    Number of times pregnant  ...  Class variable
# 0                         6  ...               1
# 1                         1  ...               0
# 2                         8  ...               1
# 3                         1  ...               0
# 4                         0  ...               1
#
# [5 rows x 9 columns]

# %%
diabetes
# Out:
#      Number of times pregnant  ...  Class variable
# 0                           6  ...               1
# 1                           1  ...               0
# 2                           8  ...               1
# 3                           1  ...               0
# 4                           0  ...               1
# ..                        ...  ...             ...
# 763                        10  ...               0
# 764                         2  ...               0
# 765                         5  ...               0
# 766                         1  ...               1
# 767                         1  ...               0
#
# [768 rows x 9 columns]

# %%
from pycaret.classification import *
clfi = setup(data = diabetes , target = 'Class variable')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_c593aa54_c474_11ea_b26a_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c593aa54_c474_11ea_b26a_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c593aa54_c474_11ea_b26a_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_c593aa54_c474_11ea_b26a_0242ac1c0002row0_col1" class="data row0 col1" >4650</td>
#             </tr>
#             <tr>
#                         <th id="T_c593aa54_c474_11ea_b26a_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c593aa54_c474_11ea_b26a_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
# ...

# %%
##comparing models
compare_models()
# Out:
# <style  type="text/css" >
#     #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002 th {
#           text-align: left;
#     }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_ff5cea7a_c474_11ea_b26a_0242ac1c0002row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
# ...

# %%
#ridge classifier code = ridge , selecting models 
ridge_classifier = create_model("ridge")
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.7593  0.0  0.6842  0.6500  0.6667  0.4785
# 1       0.8148  0.0  0.5789  0.8462  0.6875  0.5624
# 2       0.7593  0.0  0.5789  0.6875  0.6286  0.4524
# 3       0.6852  0.0  0.4737  0.5625  0.5143  0.2839
# 4       0.7593  0.0  0.6316  0.6667  0.6486  0.4658
# 5       0.7778  0.0  0.5263  0.7692  0.6250  0.4749
# 6       0.7963  0.0  0.6316  0.7500  0.6857  0.5367
# 7       0.7925  0.0  0.5000  0.8182  0.6207  0.4890
# 8       0.7925  0.0  0.5556  0.7692  0.6452  0.5038
# 9       0.7736  0.0  0.4444  0.8000  0.5714  0.4342
# Mean    0.7710  0.0  0.5605  0.7319  0.6294  0.4682
# SD      0.0336  0.0  0.0721  0.0836  0.0503  0.0713

# %%
ridge_classifier
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=4650,
#                 solver='auto', tol=0.001)

# %%
#hyperparameter tuning
tuned = tune_model('ridge')
# Out:
#       Accuracy  AUC  Recall   Prec.      F1   Kappa
# 0       0.7407  0.0  0.6316  0.6316  0.6316  0.4316
# 1       0.8148  0.0  0.5789  0.8462  0.6875  0.5624
# 2       0.7593  0.0  0.5789  0.6875  0.6286  0.4524
# 3       0.6852  0.0  0.4737  0.5625  0.5143  0.2839
# 4       0.7778  0.0  0.6316  0.7059  0.6667  0.5008
# 5       0.7593  0.0  0.4737  0.7500  0.5806  0.4236
# 6       0.7963  0.0  0.6316  0.7500  0.6857  0.5367
# 7       0.7736  0.0  0.4444  0.8000  0.5714  0.4342
# 8       0.7925  0.0  0.5556  0.7692  0.6452  0.5038
# 9       0.7925  0.0  0.5000  0.8182  0.6207  0.4890
# Mean    0.7692  0.0  0.5500  0.7321  0.6232  0.4618
# SD      0.0347  0.0  0.0685  0.0828  0.0518  0.0739

# %%
ridge_classifier
# Out:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=4650,
#                 solver='auto', tol=0.001)

# %%
ridge_classifier.predict()
#for prediciton

# %%
#ENSEMBLE MODEL

# %%
from pycaret.datasets import get_data
dia =  get_data('diabetes')
from pycaret.classification import *
clf1 = setup(data=dia,target='Class variable')
dt = create_model('dt')
dt_bag = ensemble_model(dt)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.7778  0.8308  0.5789  0.7333  0.6471  0.4882
# 1       0.7963  0.8421  0.5789  0.7857  0.6667  0.5248
# 2       0.7963  0.7962  0.6316  0.7500  0.6857  0.5367
# 3       0.7407  0.7910  0.5263  0.6667  0.5882  0.4028
# 4       0.7037  0.7526  0.5789  0.5789  0.5789  0.3504
# 5       0.6111  0.6211  0.4211  0.4444  0.4324  0.1370
# 6       0.6296  0.6376  0.3158  0.4615  0.3750  0.1248
# 7       0.7358  0.8389  0.5556  0.6250  0.5882  0.3948
# 8       0.7736  0.8087  0.5556  0.7143  0.6250  0.4664
# 9       0.7925  0.8016  0.5556  0.7692  0.6452  0.5038
# Mean    0.7357  0.7721  0.5298  0.6529  0.5832  0.3930
# SD      0.0645  0.0757  0.0879  0.1172  0.0966  0.1429

# %%
dt_bag
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                         class_weight=None,
#                                                         criterion='gini',
#                                                         max_depth=None,
#                                                         max_features=None,
#                                                         max_leaf_nodes=None,
#                                                         min_impurity_decrease=0.0,
#                                                         min_impurity_split=None,
#                                                         min_samples_leaf=1,
#                                                         min_samples_split=2,
#                                                         min_weight_fraction_leaf=0.0,
#                                                         presort='deprecated',
# ...

# %%
#Regression

boston = get_data('boston')
from pycaret.regression import *
reg1 = setup(data=boston,target= "medv")
dt = create_model('dt')
dt_boosted = ensemble_model(dt)
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.3903  11.3315  3.3662  0.8179  0.1191  0.0995
# 1     2.1450   8.8264  2.9709  0.9013  0.1141  0.0911
# 2     3.0892  31.0643  5.5735  0.7469  0.1935  0.1417
# 3     2.7142  10.9088  3.3028  0.7479  0.1551  0.1429
# 4     2.8257  27.1674  5.2122  0.6900  0.1871  0.1311
# 5     3.2011  20.4746  4.5249  0.7847  0.2327  0.2004
# 6     2.5566  15.6092  3.9509  0.8111  0.2408  0.1878
# 7     1.9897   7.1394  2.6720  0.8868  0.1078  0.0943
# 8     2.5251  12.3679  3.5168  0.8856  0.1333  0.1109
# 9     2.0063  10.1107  3.1797  0.8811  0.1160  0.0855
# Mean  2.5443  15.5000  3.8270  0.8153  0.1600  0.1285
# SD    0.4021   7.7129  0.9242  0.0690  0.0478  0.0383

# %%
dt_boosted
# Out:
# BaggingRegressor(base_estimator=DecisionTreeRegressor(ccp_alpha=0.0,
#                                                       criterion='mse',
#                                                       max_depth=None,
#                                                       max_features=None,
#                                                       max_leaf_nodes=None,
#                                                       min_impurity_decrease=0.0,
#                                                       min_impurity_split=None,
#                                                       min_samples_leaf=1,
#                                                       min_samples_split=2,
#                                                       min_weight_fraction_leaf=0.0,
#                                                       presort='deprecated',
#                                                       random_state=5965,
#                                                       splitter='best'),
# ...

# %%
boston = get_data('boston')
from pycaret.regression import *
reg1 = setup(data=boston,target= "medv")
compare_models()
# Out:
# <style  type="text/css" >
#     #T_77aecd76_c476_11ea_b26a_0242ac1c0002 th {
#           text-align: left;
#     }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col4 {
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_77aecd76_c476_11ea_b26a_0242ac1c0002row0_col6 {
#             background-color:  yellow;
# ...

# %%
mymodel = create_model('catboost')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.2501   7.8449  2.8009  0.9063  0.1223  0.1058
# 1     2.0062   7.0045  2.6466  0.9152  0.1878  0.1487
# 2     2.5921  15.6326  3.9538  0.8877  0.1872  0.1498
# 3     2.7881  22.9578  4.7914  0.7236  0.1733  0.1263
# 4     1.7201   5.0430  2.2457  0.9221  0.0921  0.0743
# 5     2.5238  16.2534  4.0315  0.8596  0.1531  0.0977
# 6     1.7929   6.4539  2.5405  0.8718  0.1244  0.0813
# 7     2.4270  12.4490  3.5283  0.8591  0.1703  0.1310
# 8     2.2654   9.7018  3.1148  0.8614  0.1899  0.1577
# 9     1.5618   5.0987  2.2580  0.9256  0.1127  0.0789
# Mean  2.1928  10.8439  3.1911  0.8732  0.1513  0.1152
# SD    0.3877   5.5901  0.8127  0.0558  0.0339  0.0300

# %%
mymodel
